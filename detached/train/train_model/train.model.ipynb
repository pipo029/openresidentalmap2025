# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import font_manager

# %matplotlib inline

# 日本語フォントの設定
font_path = 'C:/Windows/Fonts/msgothic.ttc'  # MS Gothicフォントのパス
font_manager.fontManager.addfont(font_path)
plt.rcParams['font.family'] = 'MS Gothic'

# %%
#モデルの学習

import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from shapely.wkt import loads
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import KFold, train_test_split
import shap
import optuna
from sklearn.metrics import confusion_matrix

class Train_model:
    def __init__(self, 
                 teacher_data_path,
                 target_usage,
                 model_output_path
                 ):
        self.teacher_data_path = teacher_data_path
        self.target_usage = target_usage
        self.X_train = None
        self.Y_train = None
        self.X_test = None
        self.Y_test = None
        self.teacher_data = None
        self.model_output_path = model_output_path

    def load_data(self):
        self.teacher_data = gpd.read_parquet(self.teacher_data_path)
    
    def target_variable(self):
        # 目的変数の追加
        self.teacher_data['target'] = self.teacher_data['usage'] == self.target_usage
        self.teacher_data['target'] = self.teacher_data['target'].astype(int)
    
    def clean_data(self):
        need_col = ['年少人口', '生産年齢人口', '老年人口', 
                    '出生時から', '1年未満', '1年以上5年未満', '5年以上10年未満',
                    '10年以上20年未満', '20年以上', '01_500万円未満', '07_500～1000万円未満','09_1000以上',
                    '一戸建', '長屋建', '共同住宅',
                    
                    'area', 'rectangularity', 'convexity',
                    'moment_of_inertia', 'num_corners', 'anisotropy', 'longest_axis',
                    'elongation', 'orientation', 
                    'target']
        
        self.teacher_data = self.teacher_data[need_col]

    def prepare_train(self):
        df = self.teacher_data.copy()
        
        self.X_train, self.X_test, self.Y_train, self.Y_test = train_test_split(
            df.drop(columns='target'), df["target"], test_size=0.3, random_state=1
        )
        
    def objective(self, trial):
        params = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
            'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
            'seed': 42
        }

        # 交差検証
        kf = KFold(n_splits=3, shuffle=True, random_state=42)
        f1_list = []
        for fold, (train_index, val_index) in enumerate(kf.split(self.X_train)):
            X_train_fold, X_val_fold = self.X_train.iloc[train_index], self.X_train.iloc[val_index]
            y_train_fold, y_val_fold = self.Y_train.iloc[train_index], self.Y_train.iloc[val_index]
            
            # DMatrix形式に変換
            dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
            dval = xgb.DMatrix(X_val_fold, label=y_val_fold)

            # モデルを学習
            evals = [(dtrain, 'train'), (dval, 'eval')]
            model = xgb.train(params, dtrain, num_boost_round=100, evals=evals,
                              early_stopping_rounds=10, verbose_eval=False)

            preds_proba = model.predict(dval)
            preds = (preds_proba >= 0.5).astype(int)

            f1 = f1_score(y_val_fold, preds)
            f1_list.append(f1)

        return np.mean(f1_list)

    # モデルを最適化する関数
    def optimize_xgb_with_optuna(self):
        # Optunaのstudyを作成
        study = optuna.create_study(direction='maximize')
        study.optimize(lambda trial: self.objective(trial), n_trials=50)
        best_params = study.best_trial.params
        
        # 最適なハイパーパラメータを表示
        print('Best trial: ', best_params)

        # 最適なハイパーパラメータで最終モデルをトレーニング
        models = []

        # 各foldの予測精度を格納するリスト
        accuracy_list = []
        precision_list = []
        recall_list = []
        f1_list = []

        # feature importancesを格納するDataFrame
        feature_importances_df = pd.DataFrame()

        # 追加: 最も高いF1スコアとそのモデルを追跡するための変数
        best_f1_score_overall = -1.0 # F1スコアの初期値は-1.0 (最小値)
        best_f1_model = None # 最も良いモデルを格納する変数

        #交差検証
        kf = KFold(n_splits=3, shuffle=True, random_state=42)
        for fold, (train_index, val_index) in enumerate(kf.split(self.X_train)):
            x_train_fold, x_val_fold = self.X_train.iloc[train_index], self.X_train.iloc[val_index]
            y_train_fold, y_val_fold = self.Y_train.iloc[train_index], self.Y_train.iloc[val_index]

            # DMatrix形式に変換
            dtrain = xgb.DMatrix(x_train_fold, label=y_train_fold)
            dval = xgb.DMatrix(x_val_fold, label=y_val_fold)
            dtest = xgb.DMatrix(self.X_test, label=self.Y_test) 

            # モデルを学習
            model = xgb.train(best_params, dtrain, num_boost_round=100, evals=[(dtrain, 'train'), (dval, 'eval')],
                              early_stopping_rounds=10, verbose_eval=False)
            
            # 検証データ(validation data)で最適な閾値を探す
            val_preds_proba = model.predict(dval)
            best_threshold = 0
            best_f1 = 0
            # 0.01から0.99まで0.01刻みで閾値を試す
            for threshold in np.arange(0.01, 1.0, 0.01):
                val_preds = (val_preds_proba >= threshold).astype(int)
                f1 = f1_score(y_val_fold, val_preds)
                if f1 > best_f1:
                    best_f1 = f1
                    best_threshold = threshold

            print(f"Fold {fold + 1} - Found Best Threshold: {best_threshold:.2f} (with F1 score: {best_f1:.4f} on validation set)")
            
            # feature importancesを取得
            feature_importances = pd.DataFrame()
            feature_importances["feature"] = self.X_train.columns
            # XGBoostの特徴量重要度を取得し、存在しない特徴量の重要度を0に設定
            importance_dict = model.get_score(importance_type='weight')
            feature_importances["importance"] = feature_importances["feature"].map(importance_dict).fillna(0)
            feature_importances["fold"] = fold
            feature_importances_df = pd.concat([feature_importances_df, feature_importances], axis=0)

            preds_proba = model.predict(dtest)

            # 予測結果を取得（さきほど見つけた最適な閾値を使用）
            preds = (preds_proba >= best_threshold).astype(int)

            print("=" * 50)
            print(f"Start of Fold {fold + 1}")

            accuracy = accuracy_score(self.Y_test, preds)
            precision = precision_score(self.Y_test, preds)
            recall = recall_score(self.Y_test, preds)
            f1 = f1_score(self.Y_test, preds)

            # 追加: 最も高いF1スコアを持つモデルを更新
            if f1 > best_f1_score_overall:
                best_f1_score_overall = f1
                best_f1_model = model # モデルオブジェクトを保存
                print(f"  New best F1 score found: {best_f1_score_overall:.4f} in Fold {fold + 1}")

            # 混同行列を取得して先に表示（数値）
            cm = confusion_matrix(self.Y_test, preds)
            cm_float = cm.astype(float)
            print(f"Fold {fold + 1} - Confusion Matrix (Precise Values):\n{cm_float}")
            
            # 表示
            print("\n===== 最適化されたハイパーパラメータ =====")
            for key, val in best_params.items():
                print(f"  {key}: {val}")


            print("\n===== 最適な閾値 =====")
            print(f"  Best Threshold: {best_threshold:.2f}")
            
            # スコアも表示
            print("\n===== スコア =====")
            print(f"Fold {fold + 1} - Test Set Results:")
            print(f"Accuracy: {accuracy:.3f}")
            print(f"Precision: {precision:.3f}")
            print(f"Recall: {recall:.3f}")
            print(f"F1 Score: {f1:.3f}")
            print("-" * 40)

            # プロットは最後に            
            plt.figure(figsize=(6, 5))
            sns.heatmap(cm_float, annot=True, fmt=".10g", cmap='Blues')
            plt.title(f"Confusion Matrix - Fold {fold + 1}")
            plt.xlabel("Predicted Label")
            plt.ylabel("True Label")
            plt.show()
            
            print(f"End of Fold {fold + 1}")
            print("=" * 50)
            
            models.append(model)

        # 追加: 交差検証ループ終了後に、最もF1スコアが高かったモデルを保存
        if best_f1_model is not None:
            best_f1_model.save_model(self.model_output_path)
            print(f"modelのセーブ完了")
        else:
            print("\nNo model was saved (best_f1_model is None).")

        mean_feature_importances = feature_importances_df.groupby("feature")["importance"].mean().reset_index()
        mean_feature_importances = mean_feature_importances.sort_values(by="importance", ascending=False)
        
        plt.figure(figsize=(16, 10))
        mean_feature_importances_20 = mean_feature_importances
        sns.barplot(x="importance", y="feature", data=mean_feature_importances_20, palette="viridis")
        plt.xlabel("重要度", fontsize=20)
        plt.ylabel("特徴量", fontsize=20)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        plt.title("Mean Feature Importances (Top 20)", fontsize=22)
        plt.grid(True, linestyle='--', zorder=0)
        plt.tight_layout()
        plt.show()
        print('次のfoldに移行中')
        
        if models:
            explainer = shap.TreeExplainer(models[0])
            shap_values = explainer.shap_values(self.X_test)
            shap_df = pd.DataFrame(shap_values, columns=self.X_test.columns)
            top_10_features = shap_df.abs().mean().sort_values(ascending=False).head(10).index.tolist()
            shap.summary_plot(shap_df[top_10_features].values, self.X_test[top_10_features], plot_type='dot', show=False)
        else:
            print("No models were trained for SHAP value calculation.")

        print('次のfoldに移行中')

    def run(self):
        self.load_data()
        self.target_variable()
        self.clean_data()
        self.prepare_train()
        self.optimize_xgb_with_optuna()

# %%
# 実行ファイル
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

if __name__ == "__main__":
    #教師データのパス
    teacher_data_path = "G:/マイドライブ/akiyamalab/オープン住宅地図/dev_2025/train/feature_engineering/detached/15202.parquet"
    target_usage = '411'
    model_output_path = "G:/マイドライブ/akiyamalab/オープン住宅地図/dev_2025/train/train_model/15202_detached.json"


    train_model = Train_model(teacher_data_path,
                              target_usage,
                              model_output_path
                             )
    
    train_model.run()
# Out:
# [I 2025-07-17 17:49:11,841] A new study created in memory with name: no-name-57e70685-a394-4747-91b1-3e430bcb3f83
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:13,722] Trial 0 finished with value: 0.7958294485354566 and parameters: {'max_depth': 7, 'eta': 0.2874760950141607, 'subsample': 0.976528548505675, 'colsample_bytree': 0.7007248322104143}. Best is trial 0 with value: 0.7958294485354566.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:15,444] Trial 1 finished with value: 0.7373729257029092 and parameters: {'max_depth': 3, 'eta': 0.03564896013680253, 'subsample': 0.9686477710171755, 'colsample_bytree': 0.9543892028904049}. Best is trial 0 with value: 0.7958294485354566.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:16,726] Trial 2 finished with value: 0.7958105776418715 and parameters: {'max_depth': 8, 'eta': 0.287744339670873, 'subsample': 0.8654872724822311, 'colsample_bytree': 0.6567381166745896}. Best is trial 0 with value: 0.7958294485354566.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:18,547] Trial 3 finished with value: 0.7972979340395936 and parameters: {'max_depth': 7, 'eta': 0.09424571604293529, 'subsample': 0.5140709973289457, 'colsample_bytree': 0.5489341701318156}. Best is trial 3 with value: 0.7972979340395936.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:20,910] Trial 4 finished with value: 0.7846575511487824 and parameters: {'max_depth': 8, 'eta': 0.010218019187909363, 'subsample': 0.674994673377588, 'colsample_bytree': 0.5456395919593671}. Best is trial 3 with value: 0.7972979340395936.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:22,365] Trial 5 finished with value: 0.795573363210014 and parameters: {'max_depth': 5, 'eta': 0.2519340890755592, 'subsample': 0.5299934889002081, 'colsample_bytree': 0.6334679365494169}. Best is trial 3 with value: 0.7972979340395936.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:26,351] Trial 6 finished with value: 0.799661726965229 and parameters: {'max_depth': 10, 'eta': 0.010484070235567125, 'subsample': 0.7631517412715254, 'colsample_bytree': 0.7350463704351896}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:27,585] Trial 7 finished with value: 0.7384104701206473 and parameters: {'max_depth': 3, 'eta': 0.0471780662328226, 'subsample': 0.910238855061394, 'colsample_bytree': 0.6206761518642095}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:29,109] Trial 8 finished with value: 0.7984552133588682 and parameters: {'max_depth': 6, 'eta': 0.1794375454592261, 'subsample': 0.9093359748988039, 'colsample_bytree': 0.5871513896927775}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:30,369] Trial 9 finished with value: 0.7316581706562509 and parameters: {'max_depth': 3, 'eta': 0.029238880771722753, 'subsample': 0.9494170769819632, 'colsample_bytree': 0.6827732533978685}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:34,219] Trial 10 finished with value: 0.7981578593307318 and parameters: {'max_depth': 10, 'eta': 0.010390783209641381, 'subsample': 0.7442387266507366, 'colsample_bytree': 0.8400675448457217}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:36,429] Trial 11 finished with value: 0.7949997326980663 and parameters: {'max_depth': 10, 'eta': 0.1659284737695656, 'subsample': 0.8133671775294709, 'colsample_bytree': 0.8046145460222399}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:37,871] Trial 12 finished with value: 0.7878377175092721 and parameters: {'max_depth': 5, 'eta': 0.10355110654859803, 'subsample': 0.6575361078818278, 'colsample_bytree': 0.5003639068790376}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:39,163] Trial 13 finished with value: 0.7927350760718764 and parameters: {'max_depth': 5, 'eta': 0.4278566721866152, 'subsample': 0.8062382205119248, 'colsample_bytree': 0.7724754475196915}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:42,145] Trial 14 finished with value: 0.7967819733009797 and parameters: {'max_depth': 9, 'eta': 0.01991472605706332, 'subsample': 0.7085766631643274, 'colsample_bytree': 0.9068536853322402}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:43,827] Trial 15 finished with value: 0.7886573799858835 and parameters: {'max_depth': 6, 'eta': 0.06807511059385282, 'subsample': 0.6032807395911618, 'colsample_bytree': 0.7297054092532885}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:45,541] Trial 16 finished with value: 0.7989080441574593 and parameters: {'max_depth': 6, 'eta': 0.15143001942937281, 'subsample': 0.8137753577686675, 'colsample_bytree': 0.8589485846146179}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:48,514] Trial 17 finished with value: 0.7909997062403882 and parameters: {'max_depth': 8, 'eta': 0.01648924863070318, 'subsample': 0.8154882067566663, 'colsample_bytree': 0.8671543215109948}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:52,012] Trial 18 finished with value: 0.797340657234407 and parameters: {'max_depth': 9, 'eta': 0.12024702631181461, 'subsample': 0.7596956838033099, 'colsample_bytree': 0.9807036972455787}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:54,187] Trial 19 finished with value: 0.764590757855101 and parameters: {'max_depth': 4, 'eta': 0.06229906282644197, 'subsample': 0.8566813897509549, 'colsample_bytree': 0.7726483843324582}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:49:58,134] Trial 20 finished with value: 0.7970880955156195 and parameters: {'max_depth': 9, 'eta': 0.021051221028742597, 'subsample': 0.6107158780025366, 'colsample_bytree': 0.8904261990173428}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:00,344] Trial 21 finished with value: 0.7983074870732371 and parameters: {'max_depth': 6, 'eta': 0.17500749738159616, 'subsample': 0.8945930850353192, 'colsample_bytree': 0.5973500235659082}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:02,000] Trial 22 finished with value: 0.7987348979939567 and parameters: {'max_depth': 6, 'eta': 0.15190819428332739, 'subsample': 0.7746870905523434, 'colsample_bytree': 0.8212114574623337}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:03,863] Trial 23 finished with value: 0.7991401715769161 and parameters: {'max_depth': 7, 'eta': 0.1274512011527927, 'subsample': 0.7595418831695786, 'colsample_bytree': 0.8162160129382785}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:05,956] Trial 24 finished with value: 0.7972224970640154 and parameters: {'max_depth': 7, 'eta': 0.08263491477288522, 'subsample': 0.708265946579004, 'colsample_bytree': 0.7413502555131412}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:07,376] Trial 25 finished with value: 0.7613801836479676 and parameters: {'max_depth': 4, 'eta': 0.05106877455482627, 'subsample': 0.7245621012416485, 'colsample_bytree': 0.9435147919601923}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:10,078] Trial 26 finished with value: 0.7964042514487705 and parameters: {'max_depth': 10, 'eta': 0.13486452830792195, 'subsample': 0.7788213603459708, 'colsample_bytree': 0.7922963326142147}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:11,740] Trial 27 finished with value: 0.7963628328737778 and parameters: {'max_depth': 8, 'eta': 0.21883878864580264, 'subsample': 0.8318048326206888, 'colsample_bytree': 0.8480438427393336}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:13,152] Trial 28 finished with value: 0.7937829261553818 and parameters: {'max_depth': 4, 'eta': 0.38708593623797455, 'subsample': 0.6664532575141743, 'colsample_bytree': 0.9056051643422206}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:14,681] Trial 29 finished with value: 0.7938605280197191 and parameters: {'max_depth': 7, 'eta': 0.2942439838488546, 'subsample': 0.8520226297558116, 'colsample_bytree': 0.7090085054640096}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:16,627] Trial 30 finished with value: 0.7884766425889057 and parameters: {'max_depth': 7, 'eta': 0.038037644254666096, 'subsample': 0.7911326003883993, 'colsample_bytree': 0.6983698111574888}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:18,233] Trial 31 finished with value: 0.7972054032796199 and parameters: {'max_depth': 6, 'eta': 0.12563983069309012, 'subsample': 0.7597749175094031, 'colsample_bytree': 0.8177081545678526}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:19,903] Trial 32 finished with value: 0.7953124975437101 and parameters: {'max_depth': 5, 'eta': 0.16165370701360232, 'subsample': 0.7794762408255462, 'colsample_bytree': 0.8272615825367303}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:21,652] Trial 33 finished with value: 0.7974365790263279 and parameters: {'max_depth': 6, 'eta': 0.22229024274907996, 'subsample': 0.7407935445429258, 'colsample_bytree': 0.8747145398984408}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:23,578] Trial 34 finished with value: 0.7980884601261544 and parameters: {'max_depth': 7, 'eta': 0.08691759519979864, 'subsample': 0.8764780876468158, 'colsample_bytree': 0.7805048155527048}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:24,943] Trial 35 finished with value: 0.7956719681208316 and parameters: {'max_depth': 5, 'eta': 0.3326743313300142, 'subsample': 0.6959762106420851, 'colsample_bytree': 0.7560900195625535}. Best is trial 6 with value: 0.799661726965229.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:27,365] Trial 36 finished with value: 0.7998532544387825 and parameters: {'max_depth': 8, 'eta': 0.10405139413224229, 'subsample': 0.8331253166979589, 'colsample_bytree': 0.9153920489262539}. Best is trial 36 with value: 0.7998532544387825.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:30,311] Trial 37 finished with value: 0.800094548069942 and parameters: {'max_depth': 9, 'eta': 0.07843916887498853, 'subsample': 0.9981113622554786, 'colsample_bytree': 0.9381916748898709}. Best is trial 37 with value: 0.800094548069942.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:33,296] Trial 38 finished with value: 0.8005522893679605 and parameters: {'max_depth': 9, 'eta': 0.07641382199754099, 'subsample': 0.9867402533102938, 'colsample_bytree': 0.9313716591602642}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:36,113] Trial 39 finished with value: 0.7996406439653518 and parameters: {'max_depth': 9, 'eta': 0.05521202176143776, 'subsample': 0.9936989872985873, 'colsample_bytree': 0.939714988958711}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:39,229] Trial 40 finished with value: 0.7980318942514 and parameters: {'max_depth': 9, 'eta': 0.03899340865124623, 'subsample': 0.9564826838597296, 'colsample_bytree': 0.9957406579290189}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:42,000] Trial 41 finished with value: 0.7992831647856254 and parameters: {'max_depth': 9, 'eta': 0.05444268387206598, 'subsample': 0.9975341713296162, 'colsample_bytree': 0.9445342686708673}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:49,043] Trial 42 finished with value: 0.8003401786311545 and parameters: {'max_depth': 10, 'eta': 0.07533024643010866, 'subsample': 0.9363807346511536, 'colsample_bytree': 0.9284271214632941}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:50:56,558] Trial 43 finished with value: 0.7999019820746888 and parameters: {'max_depth': 10, 'eta': 0.07752257131858961, 'subsample': 0.9317236270269517, 'colsample_bytree': 0.9697519572616432}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:51:03,982] Trial 44 finished with value: 0.8002107697226069 and parameters: {'max_depth': 10, 'eta': 0.07908944889081916, 'subsample': 0.9304597446363254, 'colsample_bytree': 0.9746839950288391}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:51:11,464] Trial 45 finished with value: 0.8000877618765925 and parameters: {'max_depth': 10, 'eta': 0.07544137968549755, 'subsample': 0.9321042715932701, 'colsample_bytree': 0.9720490057840752}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:51:19,089] Trial 46 finished with value: 0.8001853577421129 and parameters: {'max_depth': 10, 'eta': 0.06689825593462409, 'subsample': 0.927716555726996, 'colsample_bytree': 0.9685850267395911}. Best is trial 38 with value: 0.8005522893679605.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:51:27,159] Trial 47 finished with value: 0.8005957676742196 and parameters: {'max_depth': 10, 'eta': 0.04333726698158826, 'subsample': 0.9673199949572634, 'colsample_bytree': 0.9254938630124476}. Best is trial 47 with value: 0.8005957676742196.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:51:32,087] Trial 48 finished with value: 0.7999262801102267 and parameters: {'max_depth': 10, 'eta': 0.029641998831881948, 'subsample': 0.9697102011201808, 'colsample_bytree': 0.9196851374259756}. Best is trial 47 with value: 0.8005957676742196.
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:66: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'eta': trial.suggest_loguniform('eta', 0.01, 0.5),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:67: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:68: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
# [I 2025-07-17 17:51:35,674] Trial 49 finished with value: 0.8003006389515122 and parameters: {'max_depth': 10, 'eta': 0.04258916238444814, 'subsample': 0.9340704678280181, 'colsample_bytree': 0.9963151813433742}. Best is trial 47 with value: 0.8005957676742196.
# Best trial:  {'max_depth': 10, 'eta': 0.04333726698158826, 'subsample': 0.9673199949572634, 'colsample_bytree': 0.9254938630124476}
# Fold 1 - Found Best Threshold: 0.36 (with F1 score: 0.8096 on validation set)
# ==================================================
# Start of Fold 1
#   New best F1 score found: 0.8078 in Fold 1
# Fold 1 - Confusion Matrix (Precise Values):
# [[14397.  9172.]
#  [  859. 21078.]]
#
# ===== 最適化されたハイパーパラメータ =====
#   max_depth: 10
#   eta: 0.04333726698158826
#   subsample: 0.9673199949572634
#   colsample_bytree: 0.9254938630124476
#
# ===== 最適な閾値 =====
#   Best Threshold: 0.36
#
# ===== スコア =====
# Fold 1 - Test Set Results:
# Accuracy: 0.780
# Precision: 0.697
# Recall: 0.961
# F1 Score: 0.808
# ----------------------------------------
# End of Fold 1
# ==================================================
# Fold 2 - Found Best Threshold: 0.38 (with F1 score: 0.8070 on validation set)
# ==================================================
# Start of Fold 2
#   New best F1 score found: 0.8081 in Fold 2
# Fold 2 - Confusion Matrix (Precise Values):
# [[14567.  9002.]
#  [  959. 20978.]]
#
# ===== 最適化されたハイパーパラメータ =====
#   max_depth: 10
#   eta: 0.04333726698158826
#   subsample: 0.9673199949572634
#   colsample_bytree: 0.9254938630124476
#
# ===== 最適な閾値 =====
#   Best Threshold: 0.38
#
# ===== スコア =====
# Fold 2 - Test Set Results:
# Accuracy: 0.781
# Precision: 0.700
# Recall: 0.956
# F1 Score: 0.808
# ----------------------------------------
# End of Fold 2
# ==================================================
# Fold 3 - Found Best Threshold: 0.37 (with F1 score: 0.8109 on validation set)
# ==================================================
# Start of Fold 3
#   New best F1 score found: 0.8096 in Fold 3
# Fold 3 - Confusion Matrix (Precise Values):
# [[14572.  8997.]
#  [  900. 21037.]]
#
# ===== 最適化されたハイパーパラメータ =====
#   max_depth: 10
#   eta: 0.04333726698158826
#   subsample: 0.9673199949572634
#   colsample_bytree: 0.9254938630124476
#
# ===== 最適な閾値 =====
#   Best Threshold: 0.37
#
# ===== スコア =====
# Fold 3 - Test Set Results:
# Accuracy: 0.783
# Precision: 0.700
# Recall: 0.959
# F1 Score: 0.810
# ----------------------------------------
# End of Fold 3
# ==================================================
# modelのセーブ完了
# C:\Users\0141s\AppData\Local\Temp\ipykernel_34632\6137585.py:227: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="importance", y="feature", data=mean_feature_importances_20, palette="viridis")
# 次のfoldに移行中
# 次のfoldに移行中

# %%
teacher_data = gpd.read_parquet(teacher_data_path)

# %%
teacher_data.columns
# Out:
# Index(['geometry', 'KEY_CODE', 'PREF_NAME', 'CITY_NAME', 'S_NAME', '年少人口',
#        '生産年齢人口', '老年人口', '出生時から', '1年未満', '1年以上5年未満', '5年以上10年未満',
#        '10年以上20年未満', '20年以上', '居住期間「不詳」', '00_総数', '01_500万円未満',
#        '07_500～1000万円未満', '09_1000以上', '一戸建', '長屋建', '共同住宅', 'buildingID',
#        'class', 'usage', 'area', 'perimeter', 'rectangularity', 'convexity',
#        'moment_of_inertia', 'num_corners', 'anisotropy', 'longest_axis',
#        'elongation', 'orientation', 'type_堅ろう建物', 'type_堅ろう無壁舎', 'type_普通建物',
#        'type_普通無壁舎', 'unique_id', 'center', 'buffer', '1_amenity', '1_shop',
#        '1_tourism', '3_amenity', '3_shop', '3_tourism', '5_amenity', '5_shop',
#        '5_tourism'],
#       dtype='object')

# %%
plt.figure(figsize=(16, 10))
mean_feature_importances_20 = mean_feature_importances.head(20)
sns.barplot(x="importance", y="feature", data=mean_feature_importances_20, palette="viridis")
plt.xlabel("重要度", fontsize=20)
plt.ylabel("特徴量", fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title("Mean Feature Importances (Top 20)", fontsize=22)
plt.grid(True, linestyle='--', zorder=0)
plt.tight_layout()
plt.show()
print('次のfoldに移行中')
